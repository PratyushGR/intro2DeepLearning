# %%
import numpy as np
import pandas as pd
def matcomp():
  p = np.arange(1,51).reshape(-1,1)
  y = np.arange(-20,20.1,0.1).reshape(-1,1)
  sol = y**p.T
  return pd.DataFrame(sol)

def main():
    print(matcomp())

if __name__=="__main__":
    main()
# Out:
#        0       1         2   ...            47            48            49
# 0   -20.0  400.00 -8000.000  ...  2.814750e+62 -5.629500e+63  1.125900e+65
# 1   -19.9  396.01 -7880.599  ...  2.212828e+62 -4.403528e+63  8.763020e+64
# 2   -19.8  392.04 -7762.392  ...  1.737517e+62 -3.440284e+63  6.811763e+64
# 3   -19.7  388.09 -7645.373  ...  1.362633e+62 -2.684387e+63  5.288242e+64
# 4   -19.6  384.16 -7529.536  ...  1.067312e+62 -2.091932e+63  4.100186e+64
# ..    ...     ...       ...  ...           ...           ...           ...
# 396  19.6  384.16  7529.536  ...  1.067312e+62  2.091932e+63  4.100186e+64
# 397  19.7  388.09  7645.373  ...  1.362633e+62  2.684387e+63  5.288242e+64
# 398  19.8  392.04  7762.392  ...  1.737517e+62  3.440284e+63  6.811763e+64
# 399  19.9  396.01  7880.599  ...  2.212828e+62  4.403528e+63  8.763020e+64
# 400  20.0  400.00  8000.000  ...  2.814750e+62  5.629500e+63  1.125900e+65
#
# [401 rows x 50 columns]
